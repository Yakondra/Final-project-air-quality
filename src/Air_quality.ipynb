# %% [markdown]
# # **Air Quality**
#
# ---

# %% [markdown]
# ### *Exploratory Data Analysis*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pollution_2020

# %%
pollution_2020 = pd.read_csv('../data/raw/pollution data/2020.csv', sep = ';')
pollution_2020.head()
# Out:
#    provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  dia  \
# 0         28        102         1         1   28102001_1_38  2020    1    1
# 1         28        102         1         6   28102001_6_48  2020    1    1
# 2         28        102         1         7    28102001_7_8  2020    1    1
# 3         28        102         1         8    28102001_8_8  2020    1    1
# 4         28        102         1        10  28102001_10_49  2020    1    1
#
#    h01 v01  ...   h20 v20   h21 v21   h22 v22   h23 v23   h24 v24
# 0  1,0   V  ...   1,0   V   1,0   V   1,0   V   1,0   V   1,0   V
# 1  0,3   V  ...   0,4   V   0,4   V   0,4   V   0,4   V   0,4   V
# 2  1,0   V  ...   1,0   V   1,0   V   1,0   V   1,0   V   1,0   V
# 3  8,0   V  ...   8,0   V   8,0   V   9,0   V  10,0   V   8,0   V
# 4  8,0   V  ...  16,0   V  16,0   V  17,0   V  17,0   V  17,0   V
#
# [5 rows x 56 columns]

# %%
pollution_2020.dtypes
# Out:
# provincia          int64
# municipio          int64
# estacion           int64
# magnitud           int64
# punto_muestreo    object
# ano                int64
# mes                int64
# dia                int64
# h01               object
# v01               object
# h02               object
# v02               object
# h03               object
# v03               object
# h04               object
# v04               object
# h05               object
# v05               object
# h06               object
# v06               object
# h07               object
# v07               object
# h08               object
# v08               object
# h09               object
# v09               object
# h10               object
# v10               object
# h11               object
# v11               object
# h12               object
# v12               object
# h13               object
# v13               object
# h14               object
# v14               object
# h15               object
# v15               object
# h16               object
# v16               object
# h17               object
# v17               object
# h18               object
# v18               object
# h19               object
# v19               object
# h20               object
# v20               object
# h21               object
# v21               object
# h22               object
# v22               object
# h23               object
# v23               object
# h24               object
# v24               object
# dtype: object

# %%
# # Iterar sobre todas las columnas y convertir a tipo float con reemplazo de comas por puntos
# for col in pollution_2020.columns:
#     try:
#         # Convertir la columna aplicando una función lambda que reemplace comas por puntos
#         pollution_2020[col] = pollution_2020[col].apply(lambda x: float(x.replace(',', '.')) if isinstance(x, str) else x)
#     except ValueError:
#         continue

# %%
for columna in pollution_2020:
    if pollution_2020[columna].dtype == 'object':
        try:
            pollution_2020[columna] = pollution_2020[columna].str.replace(',' , '.').astype(float)
        except ValueError:
            pass

# %%
# Eliminar filas que contienen NaN en cualquier columna
pollution_2020 = pollution_2020.dropna()

# %%
no2 = pollution_2020[pollution_2020["magnitud"] == 8]
no2
# Out:
#        provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  \
# 3             28        102         1         8    2.810200e+09  2020    1
# 8             28        120         1         8    2.812000e+09  2020    1
# 14            28        123         2         8    2.812300e+09  2020    1
# 19            28         13         2         8    2.801300e+09  2020    1
# 24            28        133         2         8    2.813300e+09  2020    1
# ...          ...        ...       ...       ...             ...   ...  ...
# 58533         28          7         4         8    2.800700e+09  2020   12
# 58538         28         74         7         8    2.807401e+09  2020   12
# 58544         28         80         3         8    2.808000e+09  2020   12
# 58549         28          9         1         8    2.800900e+09  2020   12
# 58556         28         92         5         8    2.809201e+09  2020   12
#
#        dia   h01 v01  ...   h20 v20   h21 v21   h22 v22   h23 v23   h24 v24
# 3        1   8.0   V  ...   8.0   V   8.0   V   9.0   V  10.0   V   8.0   V
# 8        1   2.0   V  ...   2.0   V   2.0   V   2.0   V   2.0   V   2.0   V
# 14       1  54.0   V  ...  65.0   V  64.0   V  62.0   V  53.0   V  46.0   V
# 19       1  15.0   V  ...  39.0   V  34.0   V  23.0   V  18.0   V  15.0   V
# 24       1  25.0   V  ...  36.0   V  34.0   V  35.0   V  31.0   V  24.0   V
# ...    ...   ...  ..  ...   ...  ..   ...  ..   ...  ..   ...  ..   ...  ..
# 58533   31  10.0   V  ...  12.0   V   6.0   V   6.0   V   2.0   V   4.0   V
# 58538   31  18.0   V  ...  15.0   V  13.0   V   9.0   V   9.0   V  15.0   V
# 58544   31   7.0   V  ...   5.0   V   3.0   V   5.0   V   5.0   V  10.0   V
# 58549   31  47.0   V  ...  18.0   V  13.0   V   9.0   V  16.0   V  16.0   V
# 58556   31  17.0   V  ...   9.0   V   7.0   V   7.0   V   5.0   V  10.0   V
#
# [7434 rows x 56 columns]
