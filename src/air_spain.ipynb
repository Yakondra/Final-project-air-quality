# %%
import pandas as pd
#pip install pandas openpyxl (para leer excels)
import numpy as np
import folium

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# **Data preprocessing**
#
# We are going to concatenate our files so we can work better with them and process the data before the EDA.

# %%
C6H6_HH_22 = pd.read_csv('../data/raw/time data 2022/C6H6_HH_2022.csv', sep = ';')
CO_HH_22 = pd.read_csv('../data/raw/time data 2022/CO_HH_2022.csv', sep= ';')
NO2_HH_22 = pd.read_csv('../data/raw/time data 2022/NO2_HH_2022.csv', sep = ';')
NOx_HH_22 = pd.read_csv('../data/raw/time data 2022/NOx_HH_2022.csv', sep = ';')
O3_HH_22 = pd.read_csv('../data/raw/time data 2022/O3_HH_2022.csv', sep = ';')
PM10_HH_22 = pd.read_csv('../data/raw/time data 2022/PM10_HH_2022.csv', sep = ';')
PM25_HH_22 = pd.read_csv('../data/raw/time data 2022/PM25_HH_2022.csv', sep = ';')
SO2_HH_22 = pd.read_csv('../data/raw/time data 2022/SO2_HH_2022.csv', sep = ';')

# %%
pollutants = pd.concat([C6H6_HH_22, CO_HH_22, NO2_HH_22, NOx_HH_22, O3_HH_22, PM10_HH_22, PM25_HH_22, SO2_HH_22])
print(pollutants.shape)
# Out:
# (819614, 32)

# %%
pollutants.head()
# Out:
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO  ANNO  MES  DIA  \
# 0          1         59         8        30  01059008_30_59  2022    1    1
# 1          1         59         8        30  01059008_30_59  2022    1    3
# 2          1         59         8        30  01059008_30_59  2022    1    4
# 3          1         59         8        30  01059008_30_59  2022    1    5
# 4          1         59         8        30  01059008_30_59  2022    1    6
#
#     H01   H02   H03   H04   H05   H06   H07   H08   H09   H10   H11   H12  \
# 0  1.58  0.73  0.55  0.68  0.65  0.72  0.56  0.59  0.56  0.84  0.87   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  0.16  0.16  0.18  0.18  0.14  0.15  0.22  0.18  0.16  0.18  0.18  0.13
# 3  0.23  0.26  0.22  0.20  0.21  0.23  0.28  0.31  0.34  0.40  0.35  0.29
# 4  0.36  0.31  0.32  0.33  0.32  0.33  0.33  0.37  0.54  0.45  0.37  0.32
#
#     H13   H14   H15   H16   H17   H18   H19   H20   H21   H22   H23   H24
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN  0.24  0.23  0.22  0.23  0.58  0.24  0.54  0.69  0.32  0.17  0.17
# 2  0.17  0.11  0.17  0.18  0.19  0.25  0.25  0.28  0.25  0.20  0.20  0.22
# 3  0.27  0.30  0.48  0.33  0.45  0.58  0.57  0.51  0.51  0.51  0.48  0.41
# 4  0.30  0.28  0.30  0.26  0.29  0.36  0.43  0.32  0.32  0.30  0.30  0.28

# %%
pollutants.to_csv('../data/processed/pollutants.csv', index= False)
pollutants = pd.read_csv('../data/processed/pollutants.csv')

# %%
total_nan = pollutants.isna().sum().sum()
total_nan
# Out:
# 367595

# %%
# Contabilizar el número de filas que contienen valores NaN creando un índice

count_nans = {}

for index, row in pollutants.iterrows():
    nans = row.isna().sum()

    if nans in count_nans:
        count_nans[nans] += 1
    else:
        count_nans[nans] =1

count_nans
# Out:
# {13: 1119,
#  0: 719282,
#  2: 23903,
#  14: 975,
#  12: 1369,
#  1: 36403,
#  3: 12238,
#  9: 1546,
#  7: 1878,
#  6: 2403,
#  8: 1659,
#  11: 1466,
#  22: 427,
#  10: 1519,
#  21: 179,
#  15: 854,
#  5: 3541,
#  16: 701,
#  4: 6208,
#  17: 658,
#  18: 524,
#  19: 286,
#  20: 245,
#  23: 231}

# %%
pollutants = pollutants.dropna()
pollutants.shape
# Out:
# (719282, 32)

# %%
pollutants.drop(['PUNTO_MUESTREO'], axis=1, inplace= True)

# %%
pollutants.shape
# Out:
# (719282, 31)

# %%
# Crear una columna 'fecha' con el año, mes y día
pollutants['FECHA'] = pd.to_datetime(pollutants[['ANNO', 'MES', 'DIA']].astype(str).agg('-'.join, axis= 1), errors='coerce', format='%Y-%m-%d')
pollutants.drop(['ANNO', 'MES', 'DIA'], axis= 1, inplace= True)

# %%
pollutants.head()
# Out:
#    PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD   H01   H02   H03   H04   H05  \
# 2          1         59         8        30  0.16  0.16  0.18  0.18  0.14
# 3          1         59         8        30  0.23  0.26  0.22  0.20  0.21
# 4          1         59         8        30  0.36  0.31  0.32  0.33  0.32
# 5          1         59         8        30  0.25  0.24  0.25  0.26  0.32
# 6          1         59         8        30  0.25  0.25  0.23  0.23  0.32
#
#     H06   H07   H08   H09   H10   H11   H12   H13   H14   H15   H16   H17  \
# 2  0.15  0.22  0.18  0.16  0.18  0.18  0.13  0.17  0.11  0.17  0.18  0.19
# 3  0.23  0.28  0.31  0.34  0.40  0.35  0.29  0.27  0.30  0.48  0.33  0.45
# 4  0.33  0.33  0.37  0.54  0.45  0.37  0.32  0.30  0.28  0.30  0.26  0.29
# 5  0.32  0.28  0.25  0.30  0.27  0.30  0.39  0.28  0.23  0.28  0.29  0.28
# 6  0.29  0.23  0.28  0.55  0.34  0.36  0.28  0.27  0.27  0.25  0.20  0.23
#
#     H18   H19   H20   H21   H22   H23   H24      FECHA
# 2  0.25  0.25  0.28  0.25  0.20  0.20  0.22 2022-01-04
# 3  0.58  0.57  0.51  0.51  0.51  0.48  0.41 2022-01-05
# 4  0.36  0.43  0.32  0.32  0.30  0.30  0.28 2022-01-06
# 5  0.32  0.31  0.23  0.25  0.29  0.29  0.28 2022-01-07
# 6  0.25  0.25  0.23  0.20  0.22  0.22  0.19 2022-01-08

# %%
measured_excel = pd.read_excel('../data/interim/Metainformacion2022.xlsx', sheet_name= 'Magnitudes')
measured_excel.head()
# Out:
#    MAGNITUD                           NOMBRE ABREVIATURA UNIDAD  \
# 0         1                DIÓXIDO DE AZUFRE         SO2  µg/m3
# 1         6              MONÓXIDO DE CARBONO          CO  mg/m3
# 2         7            MONÓXIDO DE NITRÓGENO          NO  µg/m3
# 3         8             DIÓXIDO DE NITRÓGENO         NO2  µg/m3
# 4         9  PARTÍCULAS EN SUSPENSIÓN <2,5µM       PM2.5  µg/m3
#
#                                GRUPO
# 0  Contaminantes con valor legislado
# 1  Contaminantes con valor legislado
# 2                                NaN
# 3  Contaminantes con valor legislado
# 4  Contaminantes con valor legislado

# %%
# Leer una hoja específica del archivo Excel
stations_excel= pd.read_excel('../data/interim/Metainformacion2022.xlsx', sheet_name='Estaciones')
stations_excel.head(3)
# Out:
#    COD_LOCAL  PROVINCIA  MUNICIPIO  ESTACION COD_ESTACION_DEM  \
# 0    1022001          1         22         1          ES1672A
# 1    1036004          1         36         4          ES1349A
# 2    1051001          1         51         1          ES1544A
#
#              N_RED    NOMBRE  FECHA_INI FECHA_FIN  LATITUD_G  LONGITUD_G  \
# 0  CCAA País Vasco  EL CIEGO 2004-05-10       NaT   42.51833    -2.61944
# 1  CCAA País Vasco    LLODIO 1994-01-01       NaT   43.14407    -2.96337
# 2  CCAA País Vasco   AGURAIN 1998-01-01       NaT   42.84900    -2.39370
#
#    ALTITUD      N_CCAA N_PROVINCIA            N_MUNICIPIO TIPO_ESTACION  \
# 0      480  PAÍS VASCO       ÁLAVA                ELCIEGO       TRAFICO
# 1      122  PAÍS VASCO       ÁLAVA                 LLODIO       TRAFICO
# 2      594  PAÍS VASCO       ÁLAVA  SALVATIERRA O AGURAIN         FONDO
#
#    TIPO_AREA TIPO_SUBAREA_RURAL EST                    ZONA  \
# 0  SUBURBANA                NaN  ST             RESIDENCIAL
# 1  SUBURBANA                NaN  ST   RESIDENCIAL/COMERCIAL
# 2  SUBURBANA                NaN  SF  RESIDENCIAL/INDUSTRIAL
#
#                      DIRECCION
# 0  C/GABRIEL CELAYA 8, ELCIEGO
# 1               C/ LAMUZA, S/N
# 2      CUARTEL DE LA ERTZANTZA

# %%
columnas_a_modificar = ['LATITUD_G', 'LONGITUD_G']

for columna in columnas_a_modificar:
    # Asegurarse de que todos los valores no-NaN sean strings
    # y aplicar la operación de reemplazo
    stations_excel[columna] = stations_excel[columna].apply(lambda x: str(x).replace(',', '.') if pd.notnull(x) else x)

# Después de asegurarse de que todos los valores son strings y de reemplazar las comas
# Convertimos toda la columna a float
for columna in columnas_a_modificar:
    stations_excel[columna] = stations_excel[columna].astype(float)

stations_excel.head()
# Out:
#    COD_LOCAL  PROVINCIA  MUNICIPIO  ESTACION COD_ESTACION_DEM  \
# 0    1022001          1         22         1          ES1672A
# 1    1036004          1         36         4          ES1349A
# 2    1051001          1         51         1          ES1544A
# 3    1055001          1         55         1          ES1489A
# 4    1059008          1         59         8          ES1502A
#
#              N_RED           NOMBRE  FECHA_INI FECHA_FIN  LATITUD_G  \
# 0  CCAA País Vasco         EL CIEGO 2004-05-10       NaT   42.51833
# 1  CCAA País Vasco           LLODIO 1994-01-01       NaT   43.14407
# 2  CCAA País Vasco          AGURAIN 1998-01-01       NaT   42.84900
# 3  CCAA País Vasco        VALDEREJO 1998-01-01       NaT   42.87520
# 4  CCAA País Vasco  AVENIDA GASTEIZ 1998-01-01       NaT   42.85480
#
#    LONGITUD_G  ALTITUD      N_CCAA N_PROVINCIA            N_MUNICIPIO  \
# 0    -2.61944      480  PAÍS VASCO       ÁLAVA                ELCIEGO
# 1    -2.96337      122  PAÍS VASCO       ÁLAVA                 LLODIO
# 2    -2.39370      594  PAÍS VASCO       ÁLAVA  SALVATIERRA O AGURAIN
# 3    -3.23170      911  PAÍS VASCO       ÁLAVA             VALDEGOVÍA
# 4    -2.68070      517  PAÍS VASCO       ÁLAVA        VITORIA-GASTEIZ
#
#   TIPO_ESTACION  TIPO_AREA TIPO_SUBAREA_RURAL    EST                    ZONA  \
# 0       TRAFICO  SUBURBANA                NaN     ST             RESIDENCIAL
# 1       TRAFICO  SUBURBANA                NaN     ST   RESIDENCIAL/COMERCIAL
# 2         FONDO  SUBURBANA                NaN     SF  RESIDENCIAL/INDUSTRIAL
# 3         FONDO      RURAL             REMOTA  RFREM              NATURALEZA
# 4       TRAFICO     URBANA                NaN     UT   RESIDENCIAL/COMERCIAL
#
#                      DIRECCION
# 0  C/GABRIEL CELAYA 8, ELCIEGO
# 1               C/ LAMUZA, S/N
# 2      CUARTEL DE LA ERTZANTZA
# 3  PARQUE NATURAL DE VALDEREJO
# 4            AVDA. GASTEIZ, 93

# %%
# Crear un mapa base
m = folium.Map(location=[stations_excel['LATITUD_G'].mean(), stations_excel['LONGITUD_G'].mean()], zoom_start=6)

# Añadir puntos al mapa
for idx, row in stations_excel.iterrows():
    folium.Marker(location=[row['LATITUD_G'], row['LONGITUD_G']],
                  popup=row['N_MUNICIPIO'] if 'NombrePunto' in stations_excel.columns else "Sin Nombre").add_to(m)

# Guardar el mapa en un archivo HTML
m.save('mapa.html')
#Aqui no se ve nada, creo que hay qeu hacerlo en un navegador normal

# %%
measured_dict = {}

for index, row in measured_excel.iterrows():
    measured_dict[row['MAGNITUD']] = row['ABREVIATURA']

measured_dict
# Out:
# {1: 'SO2',
#  6: 'CO',
#  7: 'NO',
#  8: 'NO2',
#  9: 'PM2.5',
#  10: 'PM10',
#  12: 'NOX',
#  14: 'O3',
#  17: 'As',
#  19: 'Pb',
#  27: 'BAP',
#  28: 'Cd',
#  30: 'C6H6',
#  62: 'NI'}

# %%
# Crear diccionario de las magnitudes 
magnitud_dict = {
    1: 'SO2',
    6: 'CO',
    7: 'NO',
    8: 'NO2',
    9: 'PM2.5',
    10: 'PM10',
    12: 'NOX',
    14: 'O3',
    17: 'As',
    19: 'Pb',
    27: 'BAP',
    28: 'Cd',
    30: 'C6H6',
    62: 'NI'
}

# %%
# Crear un diccionario para relacionar el codigo de estacion al N_municipio
dicc_codigo_muni = {}

for index, row in stations_excel.iterrows():
    dicc_codigo_muni[row['COD_ESTACION_DEM']] = row['N_MUNICIPIO']

dicc_codigo_muni
# Out:
# {'ES1672A': 'ELCIEGO',
#  'ES1349A': 'LLODIO',
#  'ES1544A': 'SALVATIERRA O AGURAIN',
#  'ES1489A': 'VALDEGOVÍA',
#  'ES1502A': 'VITORIA-GASTEIZ',
#  'ES1492A': 'VITORIA-GASTEIZ',
#  'ES1673A': 'VITORIA-GASTEIZ',
#  'ES2138A': 'ALBACETE',
#  'ES1847A': 'AGOST',
#  'ES1623A': 'ALCOY/ALCOI',
#  'ES1635A': 'ALICANTE/ALACANT',
#  'ES1915A': 'ALICANTE/ALACANT',
#  'ES1968A': 'ALICANTE/ALACANT',
#  'ES1675A': 'BENIDORM',
#  'ES1624A': 'ELCHE/ELX',
#  'ES1849A': 'ELCHE/ELX',
#  'ES1914A': 'ELDA',
#  'ES1677A': 'ORIHUELA',
#  'ES1913A': 'PINOSO',
#  'ES2008A': 'TORREVIEJA',
#  'ES1393A': 'ALMERÍA',
#  'ES1786A': 'ALMERÍA',
#  'ES1996A': 'BÉDAR',
#  'ES1785A': 'BENAHADUX',
#  'ES1845A': 'CARBONERAS',
#  'ES1547A': 'CUEVAS DEL ALMANZORA',
#  'ES0624A': 'NÍJAR',
#  'ES1835A': 'NÍJAR',
#  'ES2066A': 'NÍJAR',
#  'ES1549A': 'EJIDO (EL)',
#  'ES2029A': 'ÁVILA',
#  'ES1601A': 'BADAJOZ',
#  'ES0011R': 'BARCARROTA',
#  'ES2110A': 'BURGUILLOS DEL CERRO',
#  'ES2111A': 'JEREZ DE LOS CABALLEROS',
#  'ES2112A': 'MEDINA DE LAS TORRES',
#  'ES1819A': 'MÉRIDA',
#  'ES1820A': 'ZAFRA',
#  'ES1093A': 'ALCÚDIA',
#  'ES1517A': 'ALCÚDIA',
#  'ES1827A': 'BUNYOLA',
#  'ES1828A': 'CIUTADELLA DE MENORCA',
#  'ES2065A': 'ESCORCA',
#  'ES1246A': 'EIVISSA',
#  'ES1247A': 'EIVISSA',
#  'ES1095A': 'MAHÓN',
#  'ES2092A': 'MAHÓN',
#  'ES0006R': 'MAHÓN',
#  'ES1610A': 'PALMA DE MALLORCA',
#  'ES1604A': 'PALMA DE MALLORCA',
#  'ES1829A': 'PALMA DE MALLORCA',
#  'ES1994A': 'PALMA DE MALLORCA',
#  'ES1995A': 'PALMA DE MALLORCA',
#  'ES1518A': 'POLLENÇA',
#  'ES0296A': 'POBLA (SA)',
#  'ES1825A': 'SANT ANTONI DE PORTMANY',
#  'ES1831A': 'SANTA EULALIA DEL RÍO',
#  'ES2088A': 'AIGUAFREDA',
#  'ES1892A': 'BADALONA',
#  'ES2027A': 'BADALONA',
#  'ES0691A': 'BARCELONA',
#  'ES0559A': 'BARCELONA',
#  'ES1396A': 'BARCELONA',
#  'ES1438A': 'BARCELONA',
#  'ES1480A': 'BARCELONA',
#  'ES0567A': 'BARCELONA',
#  'ES1679A': 'BARCELONA',
#  'ES1870A': 'BARCELONA',
#  'ES1856A': 'BARCELONA',
#  'ES1900A': 'BARCELONA',
#  'ES1992A': 'BARCELONA',
#  'ES2090A': 'BARCELONA',
#  'ES1851A': 'BERGA',
#  'ES0963A': 'CASTELLBISBAL',
#  'ES1773A': 'CUBELLES',
#  'ES1910A': 'GAVÀ',
#  'ES1891A': 'GRANOLLERS',
#  'ES0692A': "HOSPITALET DE LLOBREGAT (L')",
#  'ES1135A': 'IGUALADA',
#  'ES1397A': 'MANLLEU',
#  'ES0392A': 'MANRESA',
#  'ES1125A': 'MANRESA',
#  'ES1126A': 'MARTORELL',
#  'ES1816A': 'MATARÓ',
#  'ES1841A': 'MATARÓ',
#  'ES0586A': 'MOLINS DE REI',
#  'ES1814A': 'MOLLET DEL VALLÈS',
#  'ES0584A': 'MONTCADA I REIXAC',
#  'ES1665A': 'MONTCADA I REIXAC',
#  'ES1931A': 'MONTCADA I REIXAC',
#  'ES0704A': 'MONTORNÈS DEL VALLÈS',
#  'ES1778A': 'MONTSENY',
#  'ES2012A': 'PALLEJÀ',
#  'ES1929A': 'PRAT DE LLOBREGAT (EL)',
#  'ES1983A': 'PRAT DE LLOBREGAT (EL)',
#  'ES1684A': 'RUBÍ',
#  'ES1262A': 'SABADELL',
#  'ES1148A': 'SANT ADRIÀ DE BESÒS',
#  'ES0971A': 'SANT ANDREU DE LA BARCA',
#  'ES1275A': 'SANT CELONI',
#  'ES1231A': 'SANT CUGAT DEL VALLÈS',
#  'ES1453A': 'SANTA COLOMA DE GRAMENET',
#  'ES1896A': 'SANTA MARGARIDA I ELS MONJOS',
#  'ES1899A': 'SANTA MARGARIDA I ELS MONJOS',
#  'ES1551A': 'BARBERÀ DEL VALLÈS',
#  'ES1222A': 'SANTA MARIA DE PALAUTORDERA',
#  'ES1817A': 'SANTA PERPÈTUA DE MOGODA',
#  'ES0694A': 'SANT VICENÇ DELS HORTS',
#  'ES1663A': 'SANT VICENÇ DELS HORTS',
#  'ES2011A': 'SANT VICENÇ DELS HORTS',
#  'ES1220A': 'SÚRIA',
#  'ES1018A': 'TERRASSA',
#  'ES1842A': 'TIANA',
#  'ES1923A': 'TONA',
#  'ES1642A': 'VIC',
#  'ES2087A': 'VIC',
#  'ES1903A': 'VILADECANS',
#  'ES1815A': 'VILAFRANCA DEL PENEDÈS',
#  'ES1555A': 'VILANOVA I LA GELTRÚ',
#  'ES1339A': 'VILANOVA I LA GELTRÚ',
#  'ES1986A': 'ARANDA DE DUERO',
#  'ES1160A': 'BURGOS',
#  'ES1443A': 'BURGOS',
#  'ES1987A': 'MEDINA DE POMAR',
#  'ES1346A': 'MIRANDA DE EBRO',
#  'ES1615A': 'CÁCERES',
#  'ES1997A': 'PLASENCIA',
#  'ES1616A': 'TORIL',
#  'ES1637A': 'ALGECIRAS',
#  'ES1664A': 'ALGECIRAS',
#  'ES1821A': 'ARCOS DE LA FRONTERA',
#  'ES0712A': 'BARRIOS (LOS)',
#  'ES0629A': 'BARRIOS (LOS)',
#  'ES0633A': 'BARRIOS (LOS)',
#  'ES1076A': 'BARRIOS (LOS)',
#  'ES1648A': 'BARRIOS (LOS)',
#  'ES1479A': 'CÁDIZ',
#  'ES1620A': 'JEREZ DE LA FRONTERA',
#  'ES1781A': 'JEREZ DE LA FRONTERA',
#  'ES1072A': 'LÍNEA DE LA CONCEPCIÓN (LA)',
#  'ES1634A': 'LÍNEA DE LA CONCEPCIÓN (LA)',
#  'ES1822A': 'PRADO DEL REY',
#  'ES1516A': 'PUERTO REAL',
#  'ES1593A': 'SAN FERNANDO',
#  'ES0634A': 'SAN ROQUE',
#  'ES1169A': 'SAN ROQUE',
#  'ES0556A': 'SAN ROQUE',
#  'ES0557A': 'SAN ROQUE',
#  'ES0893A': 'SAN ROQUE',
#  'ES0894A': 'SAN ROQUE',
#  'ES1074A': 'SAN ROQUE',
#  'ES1925A': 'SAN ROQUE',
#  'ES1621A': "ALCORA (L')",
#  'ES1685A': "ALCORA (L')",
#  'ES1877A': 'ALMAZORA/ALMASSORA',
#  'ES1687A': 'BENICASIM/BENICÀSSIM',
#  'ES1688A': 'BURRIANA',
#  'ES1797A': 'BURRIANA',
#  'ES1386A': 'CASTELLÓN DE LA PLANA/CASTELLÓ DE LA PLANA',
#  'ES1428A': 'CASTELLÓN DE LA PLANA/CASTELLÓ DE LA PLANA',
#  'ES1445A': 'CASTELLÓN DE LA PLANA/CASTELLÓ DE LA PLANA',
#  'ES1834A': 'CASTELLÓN DE LA PLANA/CASTELLÓ DE LA PLANA',
#  'ES1916A': 'CASTELLÓN DE LA PLANA/CASTELLÓ DE LA PLANA',
#  'ES2146A': 'CASTELLÓN DE LA PLANA/CASTELLÓ DE LA PLANA',
#  'ES1689A': 'CIRAT',
#  'ES1441A': 'MORELLA',
#  'ES1387A': 'ONDA',
#  'ES1437A': 'POBLA DE BENIFASSÀ (LA)',
#  'ES1542A': 'SAN JORGE',
#  'ES1690A': 'TORRE ENDOMÉNECH',
#  'ES1918A': "VALL D'ALBA",
#  'ES1969A': "VALL D'UIXÓ (LA)",
#  'ES1435A': 'VILLAFRANCA DEL CID',
#  'ES1622A': 'VILLARREAL/VILA-REAL',
#  'ES1691A': 'VIVER',
#  'ES1543A': 'ZORITA DEL MAESTRAZGO',
#  'ES1857A': 'CIUDAD REAL',
#  'ES1279A': 'PUERTOLLANO',
#  'ES1365A': 'PUERTOLLANO',
#  'ES2134A': 'PUERTOLLANO',
#  'ES2135A': 'PUERTOLLANO',
#  'ES1800A': 'CÓRDOBA',
#  'ES1799A': 'CÓRDOBA',
#  'ES1993A': 'CÓRDOBA',
#  'ES2047A': 'CÓRDOBA',
#  'ES0926A': 'ESPIEL',
#  'ES1972A': 'OBEJO',
#  'ES1971A': 'VILLAHARTA',
#  'ES1234A': 'ARTEIXO',
#  'ES1907A': 'ARTEIXO',
#  'ES2086A': 'ARTEIXO',
#  'ES2140A': 'ARTEIXO',
#  'ES2005A': 'CEE',
#  'ES2050A': 'CERCEDA',
#  'ES1138A': 'CORUÑA (A)',
#  'ES1798A': 'CORUÑA (A)',
#  'ES1957A': 'CORUÑA (A)',
#  'ES2048A': 'CORUÑA (A)',
#  'ES2102A': 'CURTIS',
#  'ES2006A': 'DUMBRÍA',
#  'ES1867A': 'FERROL',
#  'ES1960A': 'FERROL',
#  'ES1557A': 'LARACHA',
#  'ES2039A': 'NEDA',
#  'ES0005R': 'NOIA',
#  'ES2049A': 'ORDES',
#  'ES0201A': 'PONTES DE GARCÍA RODRÍGUEZ (AS)',
#  'ES0094A': 'PONTES DE GARCÍA RODRÍGUEZ (AS)',
#  'ES1958A': 'PONTES DE GARCÍA RODRÍGUEZ (AS)',
#  'ES1959A': 'PONTES DE GARCÍA RODRÍGUEZ (AS)',
#  'ES1309A': 'SANTIAGO DE COMPOSTELA',
#  'ES1868A': 'SANTIAGO DE COMPOSTELA',
#  'ES1901A': 'SANTIAGO DE COMPOSTELA',
#  'ES1858A': 'CUENCA',
#  'ES1201A': 'AGULLANA',
#  'ES1311A': 'BEGUR',
#  'ES1559A': "BISBAL D'EMPORDÀ (LA)",
#  'ES2099A': 'BREDA',
#  'ES0010R': 'CADAQUÉS',
#  'ES0991A': 'CASSÀ DE LA SELVA',
#  'ES1999A': 'GIRONA',
#  'ES1310A': 'PARDINES',
#  'ES1347A': 'SANTA PAU',
#  'ES1973A': 'ARMILLA',
#  'ES1560A': 'GRANADA',
#  'ES1924A': 'GRANADA',
#  'ES1370A': 'MOTRIL',
#  'ES0007R': 'VÍZNAR',
#  'ES2133A': 'AZUQUECA DE HENARES',
#  'ES0009R': 'CAMPISÁBALOS',
#  'ES1537A': 'GUADALAJARA',
#  'ES2121A': 'ANDOAIN',
#  'ES1599A': 'AIA',
#  'ES1501A': 'AZPEITIA',
#  'ES1499A': 'BEASAIN',
#  'ES2122A': 'HONDARRIBIA',
#  'ES1497A': 'HERNANI',
#  'ES1442A': 'ARRASATE O MONDRAGÓN',
#  'ES1494A': 'DONOSTIA-SAN SEBASTIÁN',
#  'ES1696A': 'DONOSTIA-SAN SEBASTIÁN',
#  'ES1697A': 'DONOSTIA-SAN SEBASTIÁN',
#  'ES2101A': 'DONOSTIA-SAN SEBASTIÁN',
#  'ES2120A': 'DONOSTIA-SAN SEBASTIÁN',
#  'ES1498A': 'TOLOSA',
#  'ES2118A': 'USURBIL',
#  'ES2103A': 'ZUMARRAGA',
#  'ES2119A': 'LASARTE-ORIA',
#  'ES1878A': 'ALMONTE',
#  'ES0017R': 'ALMONTE',
#  'ES0822A': 'HUELVA',
#  'ES1256A': 'HUELVA',
#  'ES0785A': 'HUELVA',
#  'ES1328A': 'HUELVA',
#  'ES1340A': 'HUELVA',
#  'ES1658A': 'HUELVA',
#  'ES1258A': 'MOGUER',
#  'ES1793A': 'MOGUER',
#  'ES1792A': 'MOGUER',
#  'ES1259A': 'NIEBLA',
#  'ES0892A': 'PALOS DE LA FRONTERA',
#  'ES1067A': 'PALOS DE LA FRONTERA',
#  'ES0787A': 'PALOS DE LA FRONTERA',
#  'ES0823A': 'PUNTA UMBRÍA',
#  'ES0827A': 'SAN JUAN DEL PUERTO',
#  'ES1417A': 'HUESCA',
#  'ES2041A': 'MONZÓN',
#  'ES1883A': 'PUEYO DE ARAGUÁS (EL)',
#  'ES2153A': 'SABIÑÁNIGO',
#  'ES1984A': 'SARIÑENA',
#  'ES1253A': 'BAILÉN',
#  'ES1656A': 'JAÉN',
#  'ES1824A': 'JAÉN',
#  'ES1718A': 'VILLANUEVA DEL ARZOBISPO',
#  'ES1989A': 'BURÓN',
#  'ES1591A': 'CARRACEDELO',
#  'ES2142A': 'CUBILLOS DEL SIL',
#  'ES1161A': 'LEÓN',
#  'ES1988A': 'LEÓN',
#  'ES1790A': 'PONFERRADA',
#  'ES1297A': 'ROBLA (LA)',
#  'ES2145A': 'SANCEDO',
#  'ES2106A': 'VALDERAS',
#  'ES1348A': 'BELLVER DE CERDANYA',
#  'ES2034A': 'JUNEDA',
#  'ES1225A': 'LLEIDA',
#  'ES1588A': 'PONTS',
#  'ES1982A': 'SANT ESTEVE DE LA SARGA',
#  'ES1248A': 'SORT',
#  'ES0014R': 'TORMS (ELS)',
#  'ES1649A': 'ALFARO',
#  'ES1779A': 'ARRÚBAL',
#  'ES1746A': 'GALILEA',
#  'ES1602A': 'LOGROÑO',
#  'ES1753A': 'PRADEJÓN',
#  'ES0343A': 'CERVO',
#  'ES0339A': 'XOVE',
#  'ES1905A': 'LUGO',
#  'ES1285A': 'MURAS',
#  'ES1175A': 'OUROL',
#  'ES2131A': 'SARRIA',
#  'ES0016R': 'SAVIÑAO (O)',
#  'ES1359A': 'VILALBA',
#  'ES2143A': 'BURELA',
#  'ES1563A': 'ALCALÁ DE HENARES',
#  'ES1564A': 'ALCOBENDAS',
#  'ES1890A': 'ALCORCÓN',
#  'ES1838A': 'ALGETE',
#  'ES1611A': 'ARANJUEZ',
#  'ES1801A': 'ARGANDA DEL REY',
#  'ES1802A': 'ATAZAR (EL)',
#  'ES1613A': 'COLMENAR VIEJO',
#  'ES1803A': 'COLLADO VILLALBA',
#  'ES1869A': 'COSLADA',
#  'ES1565A': 'FUENLABRADA',
#  'ES2028A': 'GETAFE',
#  'ES1805A': 'GUADALIX DE LA SIERRA',
#  'ES1567A': 'LEGANÉS',
#  'ES0115A': 'MADRID',
#  'ES0118A': 'MADRID',
#  'ES0120A': 'MADRID',
#  'ES0124A': 'MADRID',
#  'ES0125A': 'MADRID',
#  'ES0126A': 'MADRID',
#  'ES1193A': 'MADRID',
#  'ES1645A': 'MADRID',
#  'ES1422A': 'MADRID',
#  'ES1426A': 'MADRID',
#  'ES1525A': 'MADRID',
#  'ES1521A': 'MADRID',
#  'ES1532A': 'MADRID',
#  'ES1893A': 'MADRID',
#  'ES1894A': 'MADRID',
#  'ES1937A': 'MADRID',
#  'ES1938A': 'MADRID',
#  'ES1939A': 'MADRID',
#  'ES1940A': 'MADRID',
#  'ES1941A': 'MADRID',
#  'ES1942A': 'MADRID',
#  'ES1943A': 'MADRID',
#  'ES1944A': 'MADRID',
#  'ES1945A': 'MADRID',
#  'ES1946A': 'MADRID',
#  'ES1947A': 'MADRID',
#  'ES1998A': 'MADRID',
#  'ES1612A': 'MAJADAHONDA',
#  'ES1568A': 'MÓSTOLES',
#  'ES1806A': 'ORUSCO DE TAJUÑA',
#  'ES2093A': 'RASCAFRÍA',
#  'ES1807A': 'RIVAS-VACIAMADRID',
#  'ES1808A': 'SAN MARTÍN DE VALDEIGLESIAS',
#  'ES1752A': 'TORREJÓN DE ARDOZ',
#  'ES1809A': 'VALDEMORO',
#  'ES1810A': 'VILLA DEL PRADO',
#  'ES1811A': 'VILLAREJO DE SALVANÉS',
#  'ES1898A': 'CAMPILLOS',
#  'ES1751A': 'MÁLAGA',
#  'ES1750A': 'MÁLAGA',
#  'ES1897A': 'MÁLAGA',
#  'ES2031A': 'MÁLAGA',
#  'ES2107A': 'MÁLAGA',
#  'ES2030A': 'MARBELLA',
#  'ES1627A': 'ALCANTARILLA',
#  'ES1882A': 'CARAVACA DE LA CRUZ',
#  'ES0651A': 'CARTAGENA',
#  'ES1423A': 'CARTAGENA',
#  'ES1921A': 'CARTAGENA',
#  'ES2007A': 'CARTAGENA',
#  'ES1569A': 'LORCA',
#  'ES1633A': 'MURCIA',
#  'ES1749A': 'ALTSASU/ALSASUA',
#  'ES1662A': 'FUNES',
#  'ES2068A': 'LEITZA',
#  'ES2082A': 'OLITE',
#  'ES1472A': 'PAMPLONA/IRUÑA',
#  'ES1747A': 'PAMPLONA/IRUÑA',
#  'ES2108A': 'PAMPLONA/IRUÑA',
#  'ES1755A': 'SANGÜESA/ZANGOZA',
#  'ES1661A': 'TUDELA',
#  'ES2094A': 'TUDELA',
#  'ES2085A': 'XINZO DE LIMIA',
#  'ES2014A': 'LAZA',
#  'ES1096A': 'OURENSE',
#  'ES0879A': 'AVILÉS',
#  'ES0880A': 'AVILÉS',
#  'ES1320A': 'AVILÉS',
#  'ES1424A': 'AVILÉS',
#  'ES2054A': 'AVILÉS',
#  'ES1432A': 'CANGAS DEL NARCEA',
#  'ES1271A': 'GIJÓN',
#  'ES1272A': 'GIJÓN',
#  'ES1358A': 'GIJÓN',
#  'ES1974A': 'GIJÓN',
#  'ES2069A': 'GIJÓN',
#  'ES2132A': 'GIJÓN',
#  'ES0824A': 'LANGREO',
#  'ES0825A': 'LANGREO',
#  'ES1353A': 'LANGREO',
#  'ES0008R': 'LLANES',
#  'ES1651A': 'MIERES',
#  'ES1268A': 'OVIEDO',
#  'ES1269A': 'OVIEDO',
#  'ES1572A': 'OVIEDO',
#  'ES2075A': 'OVIEDO',
#  'ES1433A': 'SAN MARTÍN DEL REY AURELIO',
#  'ES2051A': 'SIERO',
#  'ES2083A': 'SOMIEDO',
#  'ES1832A': 'VENTA DE BAÑOS',
#  'ES1833A': 'VENTA DE BAÑOS',
#  'ES1287A': 'GUARDO',
#  'ES1922A': 'PALENCIA',
#  'ES1298A': 'VILLAMURIEL DE CERRATO',
#  'ES1745A': 'AGÜIMES',
#  'ES1863A': 'ARRECIFE',
#  'ES1955A': 'ARRECIFE',
#  'ES1952A': 'ARUCAS',
#  'ES0873A': 'PALMAS DE GRAN CANARIA (LAS)',
#  'ES1451A': 'PALMAS DE GRAN CANARIA (LAS)',
#  'ES1573A': 'PALMAS DE GRAN CANARIA (LAS)',
#  'ES2097A': 'PALMAS DE GRAN CANARIA (LAS)',
#  'ES1865A': 'PUERTO DEL ROSARIO',
#  'ES1866A': 'PUERTO DEL ROSARIO',
#  'ES1978A': 'PUERTO DEL ROSARIO',
#  'ES2002A': 'PUERTO DEL ROSARIO',
#  'ES2025A': 'PUERTO DEL ROSARIO',
#  'ES2116A': 'PUERTO DEL ROSARIO',
#  'ES1742A': 'SAN BARTOLOMÉ DE TIRAJANA',
#  'ES1763A': 'SAN BARTOLOMÉ DE TIRAJANA',
#  'ES2113A': 'SANTA LUCÍA DE TIRAJANA',
#  'ES1864A': 'TEGUISE',
#  'ES2080A': 'TEGUISE',
#  'ES0886A': 'TELDE',
#  'ES1919A': 'TELDE',
#  'ES2004A': 'TELDE',
#  'ES2084A': 'LALÍN',
#  'ES1366A': 'PONTEVEDRA',
#  'ES2061A': 'PONTEVEDRA',
#  'ES0961A': 'POIO',
#  'ES2015A': 'PONTEAREAS',
#  'ES1137A': 'VIGO',
#  'ES1440A': 'VIGO',
#  'ES1439A': 'VIGO',
#  'ES2063A': 'VIGO',
#  'ES1990A': 'MAÍLLO (EL)',
#  'ES1618A': 'SALAMANCA',
#  'ES1889A': 'SALAMANCA',
#  'ES1920A': 'ARAFO',
#  'ES1769A': 'ARICO',
#  'ES1768A': 'ARONA',
#  'ES1767A': 'ARONA',
#  'ES1766A': 'ARONA',
#  'ES1979A': 'BREÑA ALTA',
#  'ES1956A': 'BREÑA BAJA',
#  'ES1756A': 'CANDELARIA',
#  'ES1764A': 'CANDELARIA',
#  'ES1772A': 'CANDELARIA',
#  'ES2022A': 'CANDELARIA',
#  'ES1762A': 'GRANADILLA DE ABONA',
#  'ES1761A': 'GRANADILLA DE ABONA',
#  'ES1760A': 'GRANADILLA DE ABONA',
#  'ES1954A': 'REALEJOS (LOS)',
#  'ES2023A': 'SAN ANDRÉS Y SAUCES',
#  'ES2044A': 'SAN SEBASTIÁN DE LA GOMERA',
#  'ES2053A': 'SAN SEBASTIÁN DE LA GOMERA',
#  'ES2117A': 'SAN SEBASTIÁN DE LA GOMERA',
#  'ES1980A': 'SANTA CRUZ DE LA PALMA',
#  'ES1131A': 'SANTA CRUZ DE TENERIFE',
#  'ES1759A': 'SANTA CRUZ DE TENERIFE',
#  'ES1976A': 'SANTA CRUZ DE TENERIFE',
#  'ES1975A': 'SANTA CRUZ DE TENERIFE',
#  'ES2000A': 'SANTA CRUZ DE TENERIFE',
#  'ES2003A': 'SANTA CRUZ DE TENERIFE',
#  'ES2020A': 'SANTA CRUZ DE TENERIFE',
#  'ES2021A': 'SANTA CRUZ DE TENERIFE',
#  'ES2038A': 'SANTA CRUZ DE TENERIFE',
#  'ES2115A': 'SANTA CRUZ DE TENERIFE',
#  'ES2024A': 'VALVERDE',
#  'ES1576A': 'ASTILLERO (EL)',
#  'ES1577A': 'CAMARGO',
#  'ES1578A': 'CASTRO-URDIALES',
#  'ES1579A': 'CORRALES DE BUELNA (LOS)',
#  'ES1530A': 'REINOSA',
#  'ES1529A': 'SANTANDER',
#  'ES1580A': 'SANTANDER',
#  'ES1531A': 'TOJOS (LOS)',
#  'ES1038A': 'TORRELAVEGA',
#  'ES1037A': 'TORRELAVEGA',
#  'ES1039A': 'TORRELAVEGA',
#  'ES1967A': 'SEGOVIA',
#  'ES1640A': 'ALCALÁ DE GUADAIRA',
#  'ES1653A': 'DOS HERMANAS',
#  'ES1860A': 'GUILLENA',
#  'ES1630A': 'MAIRENA DEL ALJARAFE',
#  'ES1654A': 'SAN NICOLÁS DEL PUERTO',
#  'ES0890A': 'SEVILLA',
#  'ES0817A': 'SEVILLA',
#  'ES1450A': 'SEVILLA',
#  'ES1425A': 'SEVILLA',
#  'ES1519A': 'SEVILLA',
#  'ES1638A': 'SEVILLA',
#  'ES1644A': 'SEVILLA',
#  'ES1991A': 'MURIEL DE LA FUENTE',
#  'ES1643A': 'SORIA',
#  'ES2017A': 'ALCANAR',
#  'ES2091A': 'ALCANAR',
#  'ES1812A': 'ALCOVER',
#  'ES1909A': "AMETLLA DE MAR (L')",
#  'ES1930A': "AMETLLA DE MAR (L')",
#  'ES1215A': 'AMPOSTA',
#  'ES1754A': 'SÉNIA (LA)',
#  'ES1123A': 'CONSTANTÍ',
#  'ES1379A': 'GANDESA',
#  'ES1813A': 'GUIAMETS (ELS)',
#  'ES1122A': 'PERAFORT',
#  'ES1208A': 'REUS',
#  'ES1124A': 'TARRAGONA',
#  'ES1120A': 'TARRAGONA',
#  'ES1312A': 'TARRAGONA',
#  'ES1666A': 'TARRAGONA',
#  'ES2071A': 'TARRAGONA',
#  'ES1854A': "VANDELLÒS I L'HOSPITALET DE L'INFANT",
#  'ES1855A': "VANDELLÒS I L'HOSPITALET DE L'INFANT",
#  'ES1948A': "VANDELLÒS I L'HOSPITALET DE L'INFANT",
#  'ES2109A': 'VILA-SECA',
#  'ES1966A': 'ALCAÑIZ',
#  'ES0316A': 'CALANDA',
#  'ES2070A': 'CALANDA',
#  'ES1879A': 'CASTELNOU',
#  'ES0813A': 'CEROLLERA (LA)',
#  'ES1421A': 'TERUEL',
#  'ES1963A': 'ILLESCAS',
#  'ES0001R': 'SAN PABLO DE LOS MONTES',
#  'ES2136A': 'TALAVERA DE LA REINA',
#  'ES1818A': 'TOLEDO',
#  'ES2137A': 'YÉBENES (LOS)',
#  'ES1911A': 'ALBALAT DELS TARONGERS',
#  'ES1617A': 'ALZIRA',
#  'ES2018A': 'ALGAR DE PALANCIA',
#  'ES1709A': 'BENIGÁNIM',
#  'ES1625A': 'BURJASSOT',
#  'ES1670A': 'CAUDETE DE LAS FUENTES',
#  'ES2001A': 'CORTES DE PALLÁS',
#  'ES1181A': 'QUART DE POBLET',
#  'ES1182A': 'GANDIA',
#  'ES1711A': 'ONTINYENT',
#  'ES1826A': 'PATERNA',
#  'ES1185A': 'SAGUNTO/SAGUNT',
#  'ES1765A': 'SAGUNTO/SAGUNT',
#  'ES1884A': 'SAGUNTO/SAGUNT',
#  'ES1917A': 'TORREBAJA',
#  'ES2055A': 'TORRENT',
#  'ES1239A': 'VALENCIA',
#  'ES1619A': 'VALENCIA',
#  'ES1885A': 'VALENCIA',
#  'ES1912A': 'VALENCIA',
#  'ES1926A': 'VALENCIA',
#  'ES1970A': 'VALENCIA',
#  'ES2095A': 'VALENCIA',
#  'ES2019A': 'VILAMARXANT',
#  'ES1671A': 'VILLAR DEL ARZOBISPO',
#  'ES0012R': 'ZARRA',
#  'ES2096A': 'ÍSCAR',
#  'ES1162A': 'MEDINA DEL CAMPO',
#  'ES2169A': 'OLMEDO',
#  'ES1354A': 'VALLADOLID',
#  'ES1596A': 'VALLADOLID',
#  'ES1597A': 'VALLADOLID',
#  'ES1631A': 'VALLADOLID',
#  'ES1632A': 'VALLADOLID',
#  'ES1636A': 'VALLADOLID',
#  'ES2010A': 'VALLADOLID',
#  'ES2042A': 'VALLADOLID',
#  'ES0588A': 'ABANTO Y CIÉRVANA/ABANTO ZIERBENA',
#  'ES2124A': 'ABANTO Y CIÉRVANA/ABANTO ZIERBENA',
#  'ES2125A': 'AMOREBIETA-ETXANO',
#  'ES1712A': 'BARAKALDO',
#  'ES2058A': 'BARAKALDO',
#  'ES0805A': 'BASAURI',
#  'ES1713A': 'BILBAO',
#  'ES0041A': 'BILBAO',
#  'ES1244A': 'BILBAO',
#  'ES2126A': 'BILBAO',
#  'ES1490A': 'DURANGO',
#  'ES2129A': 'GETXO',
#  'ES2104A': 'MAÑARIA',
#  'ES1491A': 'MUNDAKA',
#  'ES0587A': 'MUSKIZ',
#  'ES2123A': 'MUSKIZ',
#  'ES1434A': 'SANTURTZI',
#  'ES2127A': 'SANTURTZI',
#  'ES2128A': 'SESTAO',
#  'ES1598A': 'ZALLA',
#  'ES0110A': 'ERANDIO',
#  'ES0333A': 'ERANDIO',
#  'ES1595A': 'SONDIKA',
#  'ES2130A': 'ZIERBENA',
#  'ES0013R': 'PEÑAUSENDE',
#  'ES1927A': 'ZAMORA',
#  'ES1418A': 'ALAGÓN',
#  'ES1400A': 'BUJARALOZ',
#  'ES1130A': 'ESCATRÓN',
#  'ES1044A': 'ZARAGOZA',
#  'ES1047A': 'ZARAGOZA',
#  'ES1090A': 'ZARAGOZA',
#  'ES1641A': 'ZARAGOZA',
#  'ES1836A': 'ZARAGOZA',
#  'ES1837A': 'ZARAGOZA',
#  'ES2064A': 'ZARAGOZA',
#  'ES2089A': 'ZARAGOZA',
#  'ES2100A': 'CEUTA'}

# %%
# Crear un diccionario para relacionar el codigo de estacion al N_PROVINCIA
dicc_codigo_prov = {}

for index, row in stations_excel.iterrows():
    dicc_codigo_prov[row['COD_ESTACION_DEM']] = row['N_PROVINCIA']

dicc_codigo_prov
# Out:
# {'ES1672A': 'ÁLAVA',
#  'ES1349A': 'ÁLAVA',
#  'ES1544A': 'ÁLAVA',
#  'ES1489A': 'ÁLAVA',
#  'ES1502A': 'ÁLAVA',
#  'ES1492A': 'ÁLAVA',
#  'ES1673A': 'ÁLAVA',
#  'ES2138A': 'ALBACETE',
#  'ES1847A': 'ALICANTE/ALACANT',
#  'ES1623A': 'ALICANTE/ALACANT',
#  'ES1635A': 'ALICANTE/ALACANT',
#  'ES1915A': 'ALICANTE/ALACANT',
#  'ES1968A': 'ALICANTE/ALACANT',
#  'ES1675A': 'ALICANTE/ALACANT',
#  'ES1624A': 'ALICANTE/ALACANT',
#  'ES1849A': 'ALICANTE/ALACANT',
#  'ES1914A': 'ALICANTE/ALACANT',
#  'ES1677A': 'ALICANTE/ALACANT',
#  'ES1913A': 'ALICANTE/ALACANT',
#  'ES2008A': 'ALICANTE/ALACANT',
#  'ES1393A': 'ALMERÍA',
#  'ES1786A': 'ALMERÍA',
#  'ES1996A': 'ALMERÍA',
#  'ES1785A': 'ALMERÍA',
#  'ES1845A': 'ALMERÍA',
#  'ES1547A': 'ALMERÍA',
#  'ES0624A': 'ALMERÍA',
#  'ES1835A': 'ALMERÍA',
#  'ES2066A': 'ALMERÍA',
#  'ES1549A': 'ALMERÍA',
#  'ES2029A': 'ÁVILA',
#  'ES1601A': 'BADAJOZ',
#  'ES0011R': 'BADAJOZ',
#  'ES2110A': 'BADAJOZ',
#  'ES2111A': 'BADAJOZ',
#  'ES2112A': 'BADAJOZ',
#  'ES1819A': 'BADAJOZ',
#  'ES1820A': 'BADAJOZ',
#  'ES1093A': 'BALEARS (ILLES)',
#  'ES1517A': 'BALEARS (ILLES)',
#  'ES1827A': 'BALEARS (ILLES)',
#  'ES1828A': 'BALEARS (ILLES)',
#  'ES2065A': 'BALEARS (ILLES)',
#  'ES1246A': 'BALEARS (ILLES)',
#  'ES1247A': 'BALEARS (ILLES)',
#  'ES1095A': 'BALEARS (ILLES)',
#  'ES2092A': 'BALEARS (ILLES)',
#  'ES0006R': 'BALEARS (ILLES)',
#  'ES1610A': 'BALEARS (ILLES)',
#  'ES1604A': 'BALEARS (ILLES)',
#  'ES1829A': 'BALEARS (ILLES)',
#  'ES1994A': 'BALEARS (ILLES)',
#  'ES1995A': 'BALEARS (ILLES)',
#  'ES1518A': 'BALEARS (ILLES)',
#  'ES0296A': 'BALEARS (ILLES)',
#  'ES1825A': 'BALEARS (ILLES)',
#  'ES1831A': 'BALEARS (ILLES)',
#  'ES2088A': 'BARCELONA',
#  'ES1892A': 'BARCELONA',
#  'ES2027A': 'BARCELONA',
#  'ES0691A': 'BARCELONA',
#  'ES0559A': 'BARCELONA',
#  'ES1396A': 'BARCELONA',
#  'ES1438A': 'BARCELONA',
#  'ES1480A': 'BARCELONA',
#  'ES0567A': 'BARCELONA',
#  'ES1679A': 'BARCELONA',
#  'ES1870A': 'BARCELONA',
#  'ES1856A': 'BARCELONA',
#  'ES1900A': 'BARCELONA',
#  'ES1992A': 'BARCELONA',
#  'ES2090A': 'BARCELONA',
#  'ES1851A': 'BARCELONA',
#  'ES0963A': 'BARCELONA',
#  'ES1773A': 'BARCELONA',
#  'ES1910A': 'BARCELONA',
#  'ES1891A': 'BARCELONA',
#  'ES0692A': 'BARCELONA',
#  'ES1135A': 'BARCELONA',
#  'ES1397A': 'BARCELONA',
#  'ES0392A': 'BARCELONA',
#  'ES1125A': 'BARCELONA',
#  'ES1126A': 'BARCELONA',
#  'ES1816A': 'BARCELONA',
#  'ES1841A': 'BARCELONA',
#  'ES0586A': 'BARCELONA',
#  'ES1814A': 'BARCELONA',
#  'ES0584A': 'BARCELONA',
#  'ES1665A': 'BARCELONA',
#  'ES1931A': 'BARCELONA',
#  'ES0704A': 'BARCELONA',
#  'ES1778A': 'BARCELONA',
#  'ES2012A': 'BARCELONA',
#  'ES1929A': 'BARCELONA',
#  'ES1983A': 'BARCELONA',
#  'ES1684A': 'BARCELONA',
#  'ES1262A': 'BARCELONA',
#  'ES1148A': 'BARCELONA',
#  'ES0971A': 'BARCELONA',
#  'ES1275A': 'BARCELONA',
#  'ES1231A': 'BARCELONA',
#  'ES1453A': 'BARCELONA',
#  'ES1896A': 'BARCELONA',
#  'ES1899A': 'BARCELONA',
#  'ES1551A': 'BARCELONA',
#  'ES1222A': 'BARCELONA',
#  'ES1817A': 'BARCELONA',
#  'ES0694A': 'BARCELONA',
#  'ES1663A': 'BARCELONA',
#  'ES2011A': 'BARCELONA',
#  'ES1220A': 'BARCELONA',
#  'ES1018A': 'BARCELONA',
#  'ES1842A': 'BARCELONA',
#  'ES1923A': 'BARCELONA',
#  'ES1642A': 'BARCELONA',
#  'ES2087A': 'BARCELONA',
#  'ES1903A': 'BARCELONA',
#  'ES1815A': 'BARCELONA',
#  'ES1555A': 'BARCELONA',
#  'ES1339A': 'BARCELONA',
#  'ES1986A': 'BURGOS',
#  'ES1160A': 'BURGOS',
#  'ES1443A': 'BURGOS',
#  'ES1987A': 'BURGOS',
#  'ES1346A': 'BURGOS',
#  'ES1615A': 'CÁCERES',
#  'ES1997A': 'CÁCERES',
#  'ES1616A': 'CÁCERES',
#  'ES1637A': 'CÁDIZ',
#  'ES1664A': 'CÁDIZ',
#  'ES1821A': 'CÁDIZ',
#  'ES0712A': 'CÁDIZ',
#  'ES0629A': 'CÁDIZ',
#  'ES0633A': 'CÁDIZ',
#  'ES1076A': 'CÁDIZ',
#  'ES1648A': 'CÁDIZ',
#  'ES1479A': 'CÁDIZ',
#  'ES1620A': 'CÁDIZ',
#  'ES1781A': 'CÁDIZ',
#  'ES1072A': 'CÁDIZ',
#  'ES1634A': 'CÁDIZ',
#  'ES1822A': 'CÁDIZ',
#  'ES1516A': 'CÁDIZ',
#  'ES1593A': 'CÁDIZ',
#  'ES0634A': 'CÁDIZ',
#  'ES1169A': 'CÁDIZ',
#  'ES0556A': 'CÁDIZ',
#  'ES0557A': 'CÁDIZ',
#  'ES0893A': 'CÁDIZ',
#  'ES0894A': 'CÁDIZ',
#  'ES1074A': 'CÁDIZ',
#  'ES1925A': 'CÁDIZ',
#  'ES1621A': 'CASTELLÓN/CASTELLÓ',
#  'ES1685A': 'CASTELLÓN/CASTELLÓ',
#  'ES1877A': 'CASTELLÓN/CASTELLÓ',
#  'ES1687A': 'CASTELLÓN/CASTELLÓ',
#  'ES1688A': 'CASTELLÓN/CASTELLÓ',
#  'ES1797A': 'CASTELLÓN/CASTELLÓ',
#  'ES1386A': 'CASTELLÓN/CASTELLÓ',
#  'ES1428A': 'CASTELLÓN/CASTELLÓ',
#  'ES1445A': 'CASTELLÓN/CASTELLÓ',
#  'ES1834A': 'CASTELLÓN/CASTELLÓ',
#  'ES1916A': 'CASTELLÓN/CASTELLÓ',
#  'ES2146A': 'CASTELLÓN/CASTELLÓ',
#  'ES1689A': 'CASTELLÓN/CASTELLÓ',
#  'ES1441A': 'CASTELLÓN/CASTELLÓ',
#  'ES1387A': 'CASTELLÓN/CASTELLÓ',
#  'ES1437A': 'CASTELLÓN/CASTELLÓ',
#  'ES1542A': 'CASTELLÓN/CASTELLÓ',
#  'ES1690A': 'CASTELLÓN/CASTELLÓ',
#  'ES1918A': 'CASTELLÓN/CASTELLÓ',
#  'ES1969A': 'CASTELLÓN/CASTELLÓ',
#  'ES1435A': 'CASTELLÓN/CASTELLÓ',
#  'ES1622A': 'CASTELLÓN/CASTELLÓ',
#  'ES1691A': 'CASTELLÓN/CASTELLÓ',
#  'ES1543A': 'CASTELLÓN/CASTELLÓ',
#  'ES1857A': 'CIUDAD REAL',
#  'ES1279A': 'CIUDAD REAL',
#  'ES1365A': 'CIUDAD REAL',
#  'ES2134A': 'CIUDAD REAL',
#  'ES2135A': 'CIUDAD REAL',
#  'ES1800A': 'CÓRDOBA',
#  'ES1799A': 'CÓRDOBA',
#  'ES1993A': 'CÓRDOBA',
#  'ES2047A': 'CÓRDOBA',
#  'ES0926A': 'CÓRDOBA',
#  'ES1972A': 'CÓRDOBA',
#  'ES1971A': 'CÓRDOBA',
#  'ES1234A': 'CORUÑA (A)',
#  'ES1907A': 'CORUÑA (A)',
#  'ES2086A': 'CORUÑA (A)',
#  'ES2140A': 'CORUÑA (A)',
#  'ES2005A': 'CORUÑA (A)',
#  'ES2050A': 'CORUÑA (A)',
#  'ES1138A': 'CORUÑA (A)',
#  'ES1798A': 'CORUÑA (A)',
#  'ES1957A': 'CORUÑA (A)',
#  'ES2048A': 'CORUÑA (A)',
#  'ES2102A': 'CORUÑA (A)',
#  'ES2006A': 'CORUÑA (A)',
#  'ES1867A': 'CORUÑA (A)',
#  'ES1960A': 'CORUÑA (A)',
#  'ES1557A': 'CORUÑA (A)',
#  'ES2039A': 'CORUÑA (A)',
#  'ES0005R': 'CORUÑA (A)',
#  'ES2049A': 'CORUÑA (A)',
#  'ES0201A': 'CORUÑA (A)',
#  'ES0094A': 'CORUÑA (A)',
#  'ES1958A': 'CORUÑA (A)',
#  'ES1959A': 'CORUÑA (A)',
#  'ES1309A': 'CORUÑA (A)',
#  'ES1868A': 'CORUÑA (A)',
#  'ES1901A': 'CORUÑA (A)',
#  'ES1858A': 'CUENCA',
#  'ES1201A': 'GIRONA',
#  'ES1311A': 'GIRONA',
#  'ES1559A': 'GIRONA',
#  'ES2099A': 'GIRONA',
#  'ES0010R': 'GIRONA',
#  'ES0991A': 'GIRONA',
#  'ES1999A': 'GIRONA',
#  'ES1310A': 'GIRONA',
#  'ES1347A': 'GIRONA',
#  'ES1973A': 'GRANADA',
#  'ES1560A': 'GRANADA',
#  'ES1924A': 'GRANADA',
#  'ES1370A': 'GRANADA',
#  'ES0007R': 'GRANADA',
#  'ES2133A': 'GUADALAJARA',
#  'ES0009R': 'GUADALAJARA',
#  'ES1537A': 'GUADALAJARA',
#  'ES2121A': 'GUIPÚZCOA',
#  'ES1599A': 'GUIPÚZCOA',
#  'ES1501A': 'GUIPÚZCOA',
#  'ES1499A': 'GUIPÚZCOA',
#  'ES2122A': 'GUIPÚZCOA',
#  'ES1497A': 'GUIPÚZCOA',
#  'ES1442A': 'GUIPÚZCOA',
#  'ES1494A': 'GUIPÚZCOA',
#  'ES1696A': 'GUIPÚZCOA',
#  'ES1697A': 'GUIPÚZCOA',
#  'ES2101A': 'GUIPÚZCOA',
#  'ES2120A': 'GUIPÚZCOA',
#  'ES1498A': 'GUIPÚZCOA',
#  'ES2118A': 'GUIPÚZCOA',
#  'ES2103A': 'GUIPÚZCOA',
#  'ES2119A': 'GUIPÚZCOA',
#  'ES1878A': 'HUELVA',
#  'ES0017R': 'HUELVA',
#  'ES0822A': 'HUELVA',
#  'ES1256A': 'HUELVA',
#  'ES0785A': 'HUELVA',
#  'ES1328A': 'HUELVA',
#  'ES1340A': 'HUELVA',
#  'ES1658A': 'HUELVA',
#  'ES1258A': 'HUELVA',
#  'ES1793A': 'HUELVA',
#  'ES1792A': 'HUELVA',
#  'ES1259A': 'HUELVA',
#  'ES0892A': 'HUELVA',
#  'ES1067A': 'HUELVA',
#  'ES0787A': 'HUELVA',
#  'ES0823A': 'HUELVA',
#  'ES0827A': 'HUELVA',
#  'ES1417A': 'HUESCA',
#  'ES2041A': 'HUESCA',
#  'ES1883A': 'HUESCA',
#  'ES2153A': 'HUESCA',
#  'ES1984A': 'HUESCA',
#  'ES1253A': 'JAÉN',
#  'ES1656A': 'JAÉN',
#  'ES1824A': 'JAÉN',
#  'ES1718A': 'JAÉN',
#  'ES1989A': 'LEÓN',
#  'ES1591A': 'LEÓN',
#  'ES2142A': 'LEÓN',
#  'ES1161A': 'LEÓN',
#  'ES1988A': 'LEÓN',
#  'ES1790A': 'LEÓN',
#  'ES1297A': 'LEÓN',
#  'ES2145A': 'LEÓN',
#  'ES2106A': 'LEÓN',
#  'ES1348A': 'LLEIDA',
#  'ES2034A': 'LLEIDA',
#  'ES1225A': 'LLEIDA',
#  'ES1588A': 'LLEIDA',
#  'ES1982A': 'LLEIDA',
#  'ES1248A': 'LLEIDA',
#  'ES0014R': 'LLEIDA',
#  'ES1649A': 'RIOJA (LA)',
#  'ES1779A': 'RIOJA (LA)',
#  'ES1746A': 'RIOJA (LA)',
#  'ES1602A': 'RIOJA (LA)',
#  'ES1753A': 'RIOJA (LA)',
#  'ES0343A': 'LUGO',
#  'ES0339A': 'LUGO',
#  'ES1905A': 'LUGO',
#  'ES1285A': 'LUGO',
#  'ES1175A': 'LUGO',
#  'ES2131A': 'LUGO',
#  'ES0016R': 'LUGO',
#  'ES1359A': 'LUGO',
#  'ES2143A': 'LUGO',
#  'ES1563A': 'MADRID',
#  'ES1564A': 'MADRID',
#  'ES1890A': 'MADRID',
#  'ES1838A': 'MADRID',
#  'ES1611A': 'MADRID',
#  'ES1801A': 'MADRID',
#  'ES1802A': 'MADRID',
#  'ES1613A': 'MADRID',
#  'ES1803A': 'MADRID',
#  'ES1869A': 'MADRID',
#  'ES1565A': 'MADRID',
#  'ES2028A': 'MADRID',
#  'ES1805A': 'MADRID',
#  'ES1567A': 'MADRID',
#  'ES0115A': 'MADRID',
#  'ES0118A': 'MADRID',
#  'ES0120A': 'MADRID',
#  'ES0124A': 'MADRID',
#  'ES0125A': 'MADRID',
#  'ES0126A': 'MADRID',
#  'ES1193A': 'MADRID',
#  'ES1645A': 'MADRID',
#  'ES1422A': 'MADRID',
#  'ES1426A': 'MADRID',
#  'ES1525A': 'MADRID',
#  'ES1521A': 'MADRID',
#  'ES1532A': 'MADRID',
#  'ES1893A': 'MADRID',
#  'ES1894A': 'MADRID',
#  'ES1937A': 'MADRID',
#  'ES1938A': 'MADRID',
#  'ES1939A': 'MADRID',
#  'ES1940A': 'MADRID',
#  'ES1941A': 'MADRID',
#  'ES1942A': 'MADRID',
#  'ES1943A': 'MADRID',
#  'ES1944A': 'MADRID',
#  'ES1945A': 'MADRID',
#  'ES1946A': 'MADRID',
#  'ES1947A': 'MADRID',
#  'ES1998A': 'MADRID',
#  'ES1612A': 'MADRID',
#  'ES1568A': 'MADRID',
#  'ES1806A': 'MADRID',
#  'ES2093A': 'MADRID',
#  'ES1807A': 'MADRID',
#  'ES1808A': 'MADRID',
#  'ES1752A': 'MADRID',
#  'ES1809A': 'MADRID',
#  'ES1810A': 'MADRID',
#  'ES1811A': 'MADRID',
#  'ES1898A': 'MÁLAGA',
#  'ES1751A': 'MÁLAGA',
#  'ES1750A': 'MÁLAGA',
#  'ES1897A': 'MÁLAGA',
#  'ES2031A': 'MÁLAGA',
#  'ES2107A': 'MÁLAGA',
#  'ES2030A': 'MÁLAGA',
#  'ES1627A': 'MURCIA',
#  'ES1882A': 'MURCIA',
#  'ES0651A': 'MURCIA',
#  'ES1423A': 'MURCIA',
#  'ES1921A': 'MURCIA',
#  'ES2007A': 'MURCIA',
#  'ES1569A': 'MURCIA',
#  'ES1633A': 'MURCIA',
#  'ES1749A': 'NAVARRA',
#  'ES1662A': 'NAVARRA',
#  'ES2068A': 'NAVARRA',
#  'ES2082A': 'NAVARRA',
#  'ES1472A': 'NAVARRA',
#  'ES1747A': 'NAVARRA',
#  'ES2108A': 'NAVARRA',
#  'ES1755A': 'NAVARRA',
#  'ES1661A': 'NAVARRA',
#  'ES2094A': 'NAVARRA',
#  'ES2085A': 'OURENSE',
#  'ES2014A': 'OURENSE',
#  'ES1096A': 'OURENSE',
#  'ES0879A': 'ASTURIAS',
#  'ES0880A': 'ASTURIAS',
#  'ES1320A': 'ASTURIAS',
#  'ES1424A': 'ASTURIAS',
#  'ES2054A': 'ASTURIAS',
#  'ES1432A': 'ASTURIAS',
#  'ES1271A': 'ASTURIAS',
#  'ES1272A': 'ASTURIAS',
#  'ES1358A': 'ASTURIAS',
#  'ES1974A': 'ASTURIAS',
#  'ES2069A': 'ASTURIAS',
#  'ES2132A': 'ASTURIAS',
#  'ES0824A': 'ASTURIAS',
#  'ES0825A': 'ASTURIAS',
#  'ES1353A': 'ASTURIAS',
#  'ES0008R': 'ASTURIAS',
#  'ES1651A': 'ASTURIAS',
#  'ES1268A': 'ASTURIAS',
#  'ES1269A': 'ASTURIAS',
#  'ES1572A': 'ASTURIAS',
#  'ES2075A': 'ASTURIAS',
#  'ES1433A': 'ASTURIAS',
#  'ES2051A': 'ASTURIAS',
#  'ES2083A': 'ASTURIAS',
#  'ES1832A': 'PALENCIA',
#  'ES1833A': 'PALENCIA',
#  'ES1287A': 'PALENCIA',
#  'ES1922A': 'PALENCIA',
#  'ES1298A': 'PALENCIA',
#  'ES1745A': 'PALMAS (LAS)',
#  'ES1863A': 'PALMAS (LAS)',
#  'ES1955A': 'PALMAS (LAS)',
#  'ES1952A': 'PALMAS (LAS)',
#  'ES0873A': 'PALMAS (LAS)',
#  'ES1451A': 'PALMAS (LAS)',
#  'ES1573A': 'PALMAS (LAS)',
#  'ES2097A': 'PALMAS (LAS)',
#  'ES1865A': 'PALMAS (LAS)',
#  'ES1866A': 'PALMAS (LAS)',
#  'ES1978A': 'PALMAS (LAS)',
#  'ES2002A': 'PALMAS (LAS)',
#  'ES2025A': 'PALMAS (LAS)',
#  'ES2116A': 'PALMAS (LAS)',
#  'ES1742A': 'PALMAS (LAS)',
#  'ES1763A': 'PALMAS (LAS)',
#  'ES2113A': 'PALMAS (LAS)',
#  'ES1864A': 'PALMAS (LAS)',
#  'ES2080A': 'PALMAS (LAS)',
#  'ES0886A': 'PALMAS (LAS)',
#  'ES1919A': 'PALMAS (LAS)',
#  'ES2004A': 'PALMAS (LAS)',
#  'ES2084A': 'PONTEVEDRA',
#  'ES1366A': 'PONTEVEDRA',
#  'ES2061A': 'PONTEVEDRA',
#  'ES0961A': 'PONTEVEDRA',
#  'ES2015A': 'PONTEVEDRA',
#  'ES1137A': 'PONTEVEDRA',
#  'ES1440A': 'PONTEVEDRA',
#  'ES1439A': 'PONTEVEDRA',
#  'ES2063A': 'PONTEVEDRA',
#  'ES1990A': 'SALAMANCA',
#  'ES1618A': 'SALAMANCA',
#  'ES1889A': 'SALAMANCA',
#  'ES1920A': 'SANTA CRUZ DE TENERIFE',
#  'ES1769A': 'SANTA CRUZ DE TENERIFE',
#  'ES1768A': 'SANTA CRUZ DE TENERIFE',
#  'ES1767A': 'SANTA CRUZ DE TENERIFE',
#  'ES1766A': 'SANTA CRUZ DE TENERIFE',
#  'ES1979A': 'SANTA CRUZ DE TENERIFE',
#  'ES1956A': 'SANTA CRUZ DE TENERIFE',
#  'ES1756A': 'SANTA CRUZ DE TENERIFE',
#  'ES1764A': 'SANTA CRUZ DE TENERIFE',
#  'ES1772A': 'SANTA CRUZ DE TENERIFE',
#  'ES2022A': 'SANTA CRUZ DE TENERIFE',
#  'ES1762A': 'SANTA CRUZ DE TENERIFE',
#  'ES1761A': 'SANTA CRUZ DE TENERIFE',
#  'ES1760A': 'SANTA CRUZ DE TENERIFE',
#  'ES1954A': 'SANTA CRUZ DE TENERIFE',
#  'ES2023A': 'SANTA CRUZ DE TENERIFE',
#  'ES2044A': 'SANTA CRUZ DE TENERIFE',
#  'ES2053A': 'SANTA CRUZ DE TENERIFE',
#  'ES2117A': 'SANTA CRUZ DE TENERIFE',
#  'ES1980A': 'SANTA CRUZ DE TENERIFE',
#  'ES1131A': 'SANTA CRUZ DE TENERIFE',
#  'ES1759A': 'SANTA CRUZ DE TENERIFE',
#  'ES1976A': 'SANTA CRUZ DE TENERIFE',
#  'ES1975A': 'SANTA CRUZ DE TENERIFE',
#  'ES2000A': 'SANTA CRUZ DE TENERIFE',
#  'ES2003A': 'SANTA CRUZ DE TENERIFE',
#  'ES2020A': 'SANTA CRUZ DE TENERIFE',
#  'ES2021A': 'SANTA CRUZ DE TENERIFE',
#  'ES2038A': 'SANTA CRUZ DE TENERIFE',
#  'ES2115A': 'SANTA CRUZ DE TENERIFE',
#  'ES2024A': 'SANTA CRUZ DE TENERIFE',
#  'ES1576A': 'CANTABRIA',
#  'ES1577A': 'CANTABRIA',
#  'ES1578A': 'CANTABRIA',
#  'ES1579A': 'CANTABRIA',
#  'ES1530A': 'CANTABRIA',
#  'ES1529A': 'CANTABRIA',
#  'ES1580A': 'CANTABRIA',
#  'ES1531A': 'CANTABRIA',
#  'ES1038A': 'CANTABRIA',
#  'ES1037A': 'CANTABRIA',
#  'ES1039A': 'CANTABRIA',
#  'ES1967A': 'SEGOVIA',
#  'ES1640A': 'SEVILLA',
#  'ES1653A': 'SEVILLA',
#  'ES1860A': 'SEVILLA',
#  'ES1630A': 'SEVILLA',
#  'ES1654A': 'SEVILLA',
#  'ES0890A': 'SEVILLA',
#  'ES0817A': 'SEVILLA',
#  'ES1450A': 'SEVILLA',
#  'ES1425A': 'SEVILLA',
#  'ES1519A': 'SEVILLA',
#  'ES1638A': 'SEVILLA',
#  'ES1644A': 'SEVILLA',
#  'ES1991A': 'SORIA',
#  'ES1643A': 'SORIA',
#  'ES2017A': 'TARRAGONA',
#  'ES2091A': 'TARRAGONA',
#  'ES1812A': 'TARRAGONA',
#  'ES1909A': 'TARRAGONA',
#  'ES1930A': 'TARRAGONA',
#  'ES1215A': 'TARRAGONA',
#  'ES1754A': 'TARRAGONA',
#  'ES1123A': 'TARRAGONA',
#  'ES1379A': 'TARRAGONA',
#  'ES1813A': 'TARRAGONA',
#  'ES1122A': 'TARRAGONA',
#  'ES1208A': 'TARRAGONA',
#  'ES1124A': 'TARRAGONA',
#  'ES1120A': 'TARRAGONA',
#  'ES1312A': 'TARRAGONA',
#  'ES1666A': 'TARRAGONA',
#  'ES2071A': 'TARRAGONA',
#  'ES1854A': 'TARRAGONA',
#  'ES1855A': 'TARRAGONA',
#  'ES1948A': 'TARRAGONA',
#  'ES2109A': 'TARRAGONA',
#  'ES1966A': 'TERUEL',
#  'ES0316A': 'TERUEL',
#  'ES2070A': 'TERUEL',
#  'ES1879A': 'TERUEL',
#  'ES0813A': 'TERUEL',
#  'ES1421A': 'TERUEL',
#  'ES1963A': 'TOLEDO',
#  'ES0001R': 'TOLEDO',
#  'ES2136A': 'TOLEDO',
#  'ES1818A': 'TOLEDO',
#  'ES2137A': 'TOLEDO',
#  'ES1911A': 'VALENCIA',
#  'ES1617A': 'VALENCIA',
#  'ES2018A': 'VALENCIA',
#  'ES1709A': 'VALENCIA',
#  'ES1625A': 'VALENCIA',
#  'ES1670A': 'VALENCIA',
#  'ES2001A': 'VALENCIA',
#  'ES1181A': 'VALENCIA',
#  'ES1182A': 'VALENCIA',
#  'ES1711A': 'VALENCIA',
#  'ES1826A': 'VALENCIA',
#  'ES1185A': 'VALENCIA',
#  'ES1765A': 'VALENCIA',
#  'ES1884A': 'VALENCIA',
#  'ES1917A': 'VALENCIA',
#  'ES2055A': 'VALENCIA',
#  'ES1239A': 'VALENCIA',
#  'ES1619A': 'VALENCIA',
#  'ES1885A': 'VALENCIA',
#  'ES1912A': 'VALENCIA',
#  'ES1926A': 'VALENCIA',
#  'ES1970A': 'VALENCIA',
#  'ES2095A': 'VALENCIA',
#  'ES2019A': 'VALENCIA',
#  'ES1671A': 'VALENCIA',
#  'ES0012R': 'VALENCIA',
#  'ES2096A': 'VALLADOLID',
#  'ES1162A': 'VALLADOLID',
#  'ES2169A': 'VALLADOLID',
#  'ES1354A': 'VALLADOLID',
#  'ES1596A': 'VALLADOLID',
#  'ES1597A': 'VALLADOLID',
#  'ES1631A': 'VALLADOLID',
#  'ES1632A': 'VALLADOLID',
#  'ES1636A': 'VALLADOLID',
#  'ES2010A': 'VALLADOLID',
#  'ES2042A': 'VALLADOLID',
#  'ES0588A': 'VIZCAYA',
#  'ES2124A': 'VIZCAYA',
#  'ES2125A': 'VIZCAYA',
#  'ES1712A': 'VIZCAYA',
#  'ES2058A': 'VIZCAYA',
#  'ES0805A': 'VIZCAYA',
#  'ES1713A': 'VIZCAYA',
#  'ES0041A': 'VIZCAYA',
#  'ES1244A': 'VIZCAYA',
#  'ES2126A': 'VIZCAYA',
#  'ES1490A': 'VIZCAYA',
#  'ES2129A': 'VIZCAYA',
#  'ES2104A': 'VIZCAYA',
#  'ES1491A': 'VIZCAYA',
#  'ES0587A': 'VIZCAYA',
#  'ES2123A': 'VIZCAYA',
#  'ES1434A': 'VIZCAYA',
#  'ES2127A': 'VIZCAYA',
#  'ES2128A': 'VIZCAYA',
#  'ES1598A': 'VIZCAYA',
#  'ES0110A': 'VIZCAYA',
#  'ES0333A': 'VIZCAYA',
#  'ES1595A': 'VIZCAYA',
#  'ES2130A': 'VIZCAYA',
#  'ES0013R': 'ZAMORA',
#  'ES1927A': 'ZAMORA',
#  'ES1418A': 'ZARAGOZA',
#  'ES1400A': 'ZARAGOZA',
#  'ES1130A': 'ZARAGOZA',
#  'ES1044A': 'ZARAGOZA',
#  'ES1047A': 'ZARAGOZA',
#  'ES1090A': 'ZARAGOZA',
#  'ES1641A': 'ZARAGOZA',
#  'ES1836A': 'ZARAGOZA',
#  'ES1837A': 'ZARAGOZA',
#  'ES2064A': 'ZARAGOZA',
#  'ES2089A': 'ZARAGOZA',
#  'ES2100A': 'CEUTA'}

# %%
# # Crear un diccionario vacío para los nombres de las provincias
# diccionario_provincias = {}

# for index, row in stations_excel.iterrows():
#     diccionario_provincias[row['PROVINCIA']] = row['N_PROVINCIA']

# diccionario_provincias

# %%
# #Crear un diccionario vacío para los nombres de los municipios
# diccionario_municipios = {}

# for index, row in stations_excel.iterrows():
#     diccionario_municipios[row['MUNICIPIO']] = row['N_MUNICIPIO']

# diccionario_municipios

# %%
# pollutants['MAGNITUD'] = pollutants['MAGNITUD'].map(measured_dict)
# pollutants['MUNICIPIO'] = pollutants['MUNICIPIO'].map(diccionario_municipios)
# pollutants['PROVINCIA'] = pollutants['PROVINCIA'].map(diccionario_provincias)
